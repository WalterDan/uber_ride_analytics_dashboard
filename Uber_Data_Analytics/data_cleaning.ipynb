# %%
import pandas as pd
import numpy as np

# %%
uber = pd.read_csv('Uber_data.csv')
uber
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
uber.describe()
# Out:
#        Avg VTAT   Avg CTAT  Cancelled Rides by Customer  \
# count   4.00000   4.000000                          0.0
# mean    9.17500  21.975000                          NaN
# std     4.70983   6.492239                          NaN
# min     4.90000  14.000000                          NaN
# 25%     5.20000  18.200000                          NaN
# 50%     9.20000  22.700000                          NaN
# 75%    13.17500  26.475000                          NaN
# max    13.40000  28.500000                          NaN
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                        0.0               1.0       4.000000
# mean                         NaN               1.0     504.250000
# std                          NaN               NaN     222.449058
# min                          NaN               1.0     237.000000
# 25%                          NaN               1.0     371.250000
# ...

# %%
uber.shape
# Out:
# (150000, 21)

# %%
uber.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
# I need to generate data for where Cancelled Rides by Driver is null
uber_copy = uber.copy()
uber_copy['Cancelled Rides by Driver'] = np.where(uber_copy['Cancelled Rides by Driver'].isnull(), 0, uber_copy['Cancelled Rides by Driver'])

# %%
uber_copy[uber_copy['Cancelled Rides by Driver'].isnull()].sort_values(by = 'Customer ID').head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 uber_copy[uber_copy[['Cancelled Rides by Driver', 'Reason for cancelling by Customer', 'Cancelled Rides by Driver', 'Driver Cancellation Reason', 'Incomplete Rides', 'Incomplete Rides Reason']].isnull()].sort_values(by = 'Customer ID').head(20)
#
# File c:\Users\Daniel\Documents\Data Analysis Bootcamp\venv\Lib\site-packages\pandas\core\frame.py:4094, in DataFrame.__getitem__(self, key)
#    4092 # Do we have a (boolean) DataFrame?
#    4093 if isinstance(key, DataFrame):
# -> 4094     return self.where(key)
#    4096 # Do we have a (boolean) 1d indexer?
#    4097 if com.is_bool_indexer(key):
#
# File c:\Users\Daniel\Documents\Data Analysis Bootcamp\venv\Lib\site-packages\pandas\core\generic.py:11003, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10996             warnings.warn(
# ...

# %%
uber_copy = uber.copy()

# %%
uber_copy
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
uber_copy['Cancelled Rides by Driver'].isnull().sum()
# Out:
# 123000

# %%
uber_copy[uber_copy[['Cancelled Rides by Customer', 'Reason for cancelling by Customer', 'Cancelled Rides by Driver', 'Driver Cancellation Reason', 'Incomplete Rides', 'Incomplete Rides Reason']].isnull()].sort_values(by = 'Customer ID')
# Out:
#        Date Time Booking ID Booking Status Customer ID Vehicle Type  \
# 0       NaN  NaN        NaN            NaN         NaN          NaN
# 1       NaN  NaN        NaN            NaN         NaN          NaN
# 2       NaN  NaN        NaN            NaN         NaN          NaN
# 3       NaN  NaN        NaN            NaN         NaN          NaN
# 4       NaN  NaN        NaN            NaN         NaN          NaN
# ...     ...  ...        ...            ...         ...          ...
# 149995  NaN  NaN        NaN            NaN         NaN          NaN
# 149996  NaN  NaN        NaN            NaN         NaN          NaN
# 149997  NaN  NaN        NaN            NaN         NaN          NaN
# 149998  NaN  NaN        NaN            NaN         NaN          NaN
# 149999  NaN  NaN        NaN            NaN         NaN          NaN
#
#        Pickup Location Drop Location  Avg VTAT  Avg CTAT  ...  \
# 0                  NaN           NaN       NaN       NaN  ...
# ...

# %%
uber_copy.iloc[:, 9:].head(50)
# Out:
#     Avg CTAT  Cancelled Rides by Customer  \
# 0        NaN                          NaN
# 1       14.0                          NaN
# 2       25.8                          NaN
# 3       28.5                          NaN
# 4       19.6                          NaN
# 5       18.1                          NaN
# 6       20.4                          NaN
# 7       16.5                          NaN
# 8        NaN                          NaN
# 9       26.0                          NaN
# 10      18.9                          NaN
# 11       NaN                          NaN
# 12       NaN                          NaN
# 13      28.2                          NaN
# 14      30.9                          NaN
# 15      36.9                          NaN
# 16      27.5                          NaN
# 17       NaN                          NaN
# 18       NaN                          1.0
# 19       NaN                          NaN
# 20      33.7                          NaN
# ...

# %%
uber_copy.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
uber_copy.head(15).sort_values(by = 'Customer ID')
# Out:
#           Date      Time    Booking ID       Booking Status   Customer ID  \
# 14  2024-10-18  18:28:53  "CNR8962232"            Completed  "CID1789354"
# 0   2024-03-23  12:29:38  "CNR5884300"      No Driver Found  "CID1982111"
# 3   2024-10-21  17:17:25  "CNR8906825"            Completed  "CID2610914"
# 13  2024-09-11  19:29:39  "CNR2987763"            Completed  "CID2669710"
# 1   2024-11-29  18:01:39  "CNR1326809"           Incomplete  "CID4604802"
# 5   2024-02-06  09:44:56  "CNR4096693"            Completed  "CID4670564"
# 9   2024-12-16  19:06:48  "CNR7721892"           Incomplete  "CID5214275"
# 12  2024-06-25  22:44:15  "CNR4386945"  Cancelled by Driver  "CID5543520"
# 10  2024-06-14  16:24:12  "CNR9070334"            Completed  "CID6680340"
# 6   2024-06-17  15:45:58  "CNR2002539"            Completed  "CID6800553"
# 11  2024-09-18  08:09:38  "CNR9551927"      No Driver Found  "CID7568143"
# 8   2024-09-14  12:49:09  "CNR4510807"      No Driver Found  "CID7873618"
# ...

# %%
uber_copy['Cancelled Rides by Customer']= uber_copy['Cancelled Rides by Customer'].fillna(0)

# %%
uber_copy.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer               0
# Reason for cancelling by Customer         0
# Cancelled Rides by Driver                 0
# Driver Cancellation Reason                0
# Incomplete Rides                          0
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
uber_copy['Reason for cancelling by Customer']= uber_copy['Reason for cancelling by Customer'].fillna('Did not cancel')

# %%
uber_copy['Cancelled Rides by Driver'] = uber_copy['Cancelled Rides by Driver'].fillna(0)

# %%
uber_copy['Driver Cancellation Reason'] = uber_copy['Driver Cancellation Reason'].fillna('Did not cancel')

# %%
uber_copy.head(20)
# Out:
#           Date      Time    Booking ID         Booking Status   Customer ID  \
# 0   2024-03-23  12:29:38  "CNR5884300"        No Driver Found  "CID1982111"
# 1   2024-11-29  18:01:39  "CNR1326809"             Incomplete  "CID4604802"
# 2   2024-08-23  08:56:10  "CNR8494506"              Completed  "CID9202816"
# 3   2024-10-21  17:17:25  "CNR8906825"              Completed  "CID2610914"
# 4   2024-09-16  22:08:00  "CNR1950162"              Completed  "CID9933542"
# 5   2024-02-06  09:44:56  "CNR4096693"              Completed  "CID4670564"
# 6   2024-06-17  15:45:58  "CNR2002539"              Completed  "CID6800553"
# 7   2024-03-19  17:37:37  "CNR6568000"              Completed  "CID8610436"
# 8   2024-09-14  12:49:09  "CNR4510807"        No Driver Found  "CID7873618"
# 9   2024-12-16  19:06:48  "CNR7721892"             Incomplete  "CID5214275"
# 10  2024-06-14  16:24:12  "CNR9070334"              Completed  "CID6680340"
# ...

# %%
uber_copy.iloc[:, 8:]
# Out:
#         Avg VTAT  Avg CTAT  Cancelled Rides by Customer  \
# 0            NaN       NaN                          0.0
# 1            4.9      14.0                          0.0
# 2           13.4      25.8                          0.0
# 3           13.1      28.5                          0.0
# 4            5.3      19.6                          0.0
# ...          ...       ...                          ...
# 149995      10.2      44.4                          0.0
# 149996       5.1      30.8                          0.0
# 149997       2.7      23.4                          0.0
# 149998       6.9      39.6                          0.0
# 149999       3.5      33.7                          0.0
#
#        Reason for cancelling by Customer  Cancelled Rides by Driver  \
# 0                         Did not cancel                        0.0
# 1                         Did not cancel                        0.0
# 2                         Did not cancel                        0.0
# ...

# %%
uber_copy['Incomplete Rides'] = uber_copy['Incomplete Rides'].fillna(0)

# %%
uber_copy.isnull().sum()
# Out:
# Date                                     0
# Time                                     0
# Booking ID                               0
# Booking Status                           0
# Customer ID                              0
# Vehicle Type                             0
# Pickup Location                          0
# Drop Location                            0
# Avg VTAT                             10500
# Avg CTAT                             48000
# Cancelled Rides by Customer              0
# Reason for cancelling by Customer        0
# Cancelled Rides by Driver                0
# Driver Cancellation Reason               0
# Incomplete Rides                         0
# Incomplete Rides Reason                  0
# Booking Value                        48000
# Ride Distance                        48000
# Driver Ratings                       57000
# Customer Rating                      57000
# Payment Method                       48000
# dtype: int64

# %%
uber_copy['Incomplete Rides Reason'] = uber_copy['Incomplete Rides Reason'].fillna('Ride Completed')

# %%
uber_copy.to_csv('Uber_data_cleaned.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 uber_copy.to_csv('Uber_data_cleaned.csv', index = False)
#
# NameError: name 'uber_copy' is not defined

# %%
uber_copy.nunique()
# Out:
# Date                                    365
# Time                                  62910
# Booking ID                           148767
# Booking Status                            5
# Customer ID                          148788
# Vehicle Type                              7
# Pickup Location                         176
# Drop Location                           176
# Avg VTAT                                181
# Avg CTAT                                351
# Cancelled Rides by Customer               2
# Reason for cancelling by Customer         6
# Cancelled Rides by Driver                 2
# Driver Cancellation Reason                5
# Incomplete Rides                          2
# Incomplete Rides Reason                   4
# Booking Value                          2566
# Ride Distance                          4901
# Driver Ratings                           21
# Customer Rating                          21
# Payment Method                            5
# dtype: int64

# %%
uber_copy.iloc[:, 10:]
# Out:
#         Cancelled Rides by Customer Reason for cancelling by Customer  \
# 0                               0.0                    Did not cancel
# 1                               0.0                    Did not cancel
# 2                               0.0                    Did not cancel
# 3                               0.0                    Did not cancel
# 4                               0.0                    Did not cancel
# ...                             ...                               ...
# 149995                          0.0                    Did not cancel
# 149996                          0.0                    Did not cancel
# 149997                          0.0                    Did not cancel
# 149998                          0.0                    Did not cancel
# 149999                          0.0                    Did not cancel
#
#         Cancelled Rides by Driver Driver Cancellation Reason  \
# 0                             0.0             Did not cancel
# ...

# %%
uber_copy.isnull().sum()
# Out:
# Date                                     0
# Time                                     0
# Booking ID                               0
# Booking Status                           0
# Customer ID                              0
# Vehicle Type                             0
# Pickup Location                          0
# Drop Location                            0
# Avg VTAT                             10500
# Avg CTAT                             48000
# Cancelled Rides by Customer              0
# Reason for cancelling by Customer        0
# Cancelled Rides by Driver                0
# Driver Cancellation Reason               0
# Incomplete Rides                         0
# Incomplete Rides Reason                  0
# Booking Value                        48000
# Ride Distance                        48000
# Driver Ratings                       57000
# Customer Rating                      57000
# Payment Method                       48000
# dtype: int64

# %%
# let's create a scatter plot to see the relationship between Cancelled rides by Customers and Book value

uber_copy = pd.read_csv('Uber_data_cleaned.csv')

# %%
uber_copy.iloc[:, 3:].head(40)
# Out:
#            Booking Status   Customer ID   Vehicle Type  \
# 0         No Driver Found  "CID1982111"          eBike
# 1              Incomplete  "CID4604802"       Go Sedan
# 2               Completed  "CID9202816"           Auto
# 3               Completed  "CID2610914"  Premier Sedan
# 4               Completed  "CID9933542"           Bike
# 5               Completed  "CID4670564"           Auto
# 6               Completed  "CID6800553"        Go Mini
# 7               Completed  "CID8610436"           Auto
# 8         No Driver Found  "CID7873618"       Go Sedan
# 9              Incomplete  "CID5214275"           Auto
# 10              Completed  "CID6680340"           Auto
# 11        No Driver Found  "CID7568143"           Auto
# 12    Cancelled by Driver  "CID5543520"          eBike
# 13              Completed  "CID2669710"        Go Mini
# 14              Completed  "CID1789354"        Go Mini
# 15              Completed  "CID5432215"           Auto
# ...

# %%
uber_copy['Incomplete Rides Reason'].unique()
# Out:
# array(['Ride Completed', 'Vehicle Breakdown', 'Other Issue',
#        'Customer Demand'], dtype=object)

# %%
uber_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        150000 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uber_copy.head(40)
# Out:
#           Date      Time    Booking ID         Booking Status   Customer ID  \
# 0   2024-03-23  12:29:38  "CNR5884300"        No Driver Found  "CID1982111"
# 1   2024-11-29  18:01:39  "CNR1326809"             Incomplete  "CID4604802"
# 2   2024-08-23  08:56:10  "CNR8494506"              Completed  "CID9202816"
# 3   2024-10-21  17:17:25  "CNR8906825"              Completed  "CID2610914"
# 4   2024-09-16  22:08:00  "CNR1950162"              Completed  "CID9933542"
# 5   2024-02-06  09:44:56  "CNR4096693"              Completed  "CID4670564"
# 6   2024-06-17  15:45:58  "CNR2002539"              Completed  "CID6800553"
# 7   2024-03-19  17:37:37  "CNR6568000"              Completed  "CID8610436"
# 8   2024-09-14  12:49:09  "CNR4510807"        No Driver Found  "CID7873618"
# 9   2024-12-16  19:06:48  "CNR7721892"             Incomplete  "CID5214275"
# 10  2024-06-14  16:24:12  "CNR9070334"              Completed  "CID6680340"
# ...

# %%
uber_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        150000 non-null  float64
# ...

# %%
uber_copy.isnull().sum()
# Out:
# Date                                     0
# Time                                     0
# Booking ID                               0
# Booking Status                           0
# Customer ID                              0
# Vehicle Type                             0
# Pickup Location                          0
# Drop Location                            0
# Avg VTAT                             10500
# Avg CTAT                             48000
# Cancelled Rides by Customer              0
# Reason for cancelling by Customer        0
# Cancelled Rides by Driver                0
# Driver Cancellation Reason               0
# Incomplete Rides                         0
# Incomplete Rides Reason                  0
# Booking Value                            0
# Ride Distance                            0
# Driver Ratings                       57000
# Customer Rating                      57000
# Payment Method                           0
# dtype: int64

# %%
uber_copy['Booking Value'] = uber_copy['Booking Value'].fillna(0)

# %%
uber_copy['Ride Distance'] = uber_copy['Ride Distance'].fillna(0)

uber_copy['Payment Method'] = uber_copy['Payment Method'].fillna('No payment made')

# %%
uber_copy.to_csv('Uber_data_cleaned.csv', index = False)

# %%
uber_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        150000 non-null  float64
# ...

# %%
uber_copy.isnull().sum()
# Out:
# Date                                     0
# Time                                     0
# Booking ID                               0
# Booking Status                           0
# Customer ID                              0
# Vehicle Type                             0
# Pickup Location                          0
# Drop Location                            0
# Avg VTAT                             10500
# Avg CTAT                             48000
# Cancelled Rides by Customer              0
# Reason for cancelling by Customer        0
# Cancelled Rides by Driver                0
# Driver Cancellation Reason               0
# Incomplete Rides                         0
# Incomplete Rides Reason                  0
# Booking Value                            0
# Ride Distance                            0
# Driver Ratings                       57000
# Customer Rating                      57000
# Payment Method                           0
# dtype: int64
